# %% [markdown]
# A Dungeons and Dragons enthusiast Cheat Sheet.
#
# This is a fun side project to make some of my nerdy friends' lives easier.  Myself iuncluded.
#
# We can start with stat rolling and die rolling formulas.

# %%
import random

# %%
def roll_stats():
    #setting user input for random seed to vary responses, yet make them repeatable for DM review
    print("Choose a number between 1 and 501")
    seed1= input()
    random.seed(seed1)
    #initalizing list to store stats after loop
    stats=[]
    #looping 7 times
    for i in range(7):
        #roll a 6-sided die 4 times and store the result
        nums = [random.randrange(1, 7, 1) for i in range(4)] 
        #sort rolls by value
        sort_nums = sorted(nums)
        #drop lowest score
        final_nums = sort_nums[1:4]
        #sum other rolls
        sums = sum(final_nums)
        #add these stats to the list 
        stats.append(sums)
    #sort all the stats generated by the loop
    sort_set = sorted(stats)
    #drop the lowest score
    set_stats = sort_set[1:7]
    #print results
    print("Your Stats are: {}".format(set_stats))

# %%
#defining a formulas to 'roll a x-sided die'
def roll(x=20):
    #default dice roller to a 20-sided die
    dice = [100,20,12,10,8,6,4,2]
    if x in dice: 
        roll = random.randrange(1, x, 1) 
        print("You rolled a {}".format(roll)) 
    else:
        print("Please Roll a standard die")

# %%
def dwarf_name(gender):
    #lists of female first name in syllables
    lady1 = ['Oct', 'Ol', 'Hel', 'Vor', 'Tial', 'Am', 'Ar', 'Bar', 'Dag', 
             'Die','Eld', 'Fin','Hly','Kris', 'Il', 'Mar', 'Tor']
    lady2 =['via','ga', 'ana', 'stra', 'sta','burr','tin','lda',
            'drin','ala','sa','llyn','dis','ja','hra', 'ra', 'drilla', 'illa']
    #lists of male first name in syllables
    gent1 = ['Thor','Og', 'Lok','Dim','Tim', 'Bal', 'Glo','Dor','Ad', 'Alber',
             'Bae','Bar','Bro', 'Dain','Delg','Ein', 'Flinn','Gar', 'Hir' ,
             'Kil','Mor','Os', 'Ram','Tak','Trau','Trav', 'Ur','Ulf']
    gent2 = ['', 'ur', 'g','men', 'in', 'dur','rn','tt', 'llick','gar', 'rik', 
             'rich', 'end','tor', 'unnar','kil', 'grimm', 'ech', 'gran', 'adin', 'ok']
    #lists of surname in syllables
    sur1 = ['Stone', 'Gem', 'Obsidian','Rock', 'Lime', 'Hill','Oak','Gran','Steel','Sword','Axe', 'Spear','Ton']
    sur2 = ['grin', 'helm', 'granit', 'fist', 'sheild', 'stein', 'guard','breaker', '','hra', 'stronn',
            'gor','stromm','rock']
    
    #creating last name
    last = sur1[random.randrange(0,len(sur1),1)]+sur2[random.randrange(0,len(sur2),1)]
    
    if gender == 'f':
        #creating first name
        n1 = lady1[random.randrange(0,len(lady1),1)]
        n2 = lady2[random.randrange(0,len(lady2),1)]
      
        return n1+n2, last
        
    if gender == 'm':
        #creating first name
        n3 = gent1[random.randrange(0,len(gent1),1)]
        n4 = gent2[random.randrange(0,len(gent2),1)]

        return n3+n4, last

# %%
def elf_name(gender):
    #list of first name prefixes
    pref = ["Ab","Ad","Aer","Ath","Aw","Arw","Bryn", "Bra","Brei","Cae","Con","Cef","Cad", "Cer",
            "Cyn","Col","Daf","Dy","Der","Dew","Ei","El","Em","En","Ew","Ff","Fo","Gar","Gaw",
            "Ger","Geth","Gly","Gri","Gwl","Gwy","Hal","Hel","Hyw","Ia","Id","Ie","If","Il",
            "Io","I","LLe","LLy","Ma","Teg","Teth","Ter"]
    
    #list of female first name suffixes
    lady = ['wynn','tha','rianna','aste','nua','rynna','rel','lynn','ilia','na','leth','shanna',
            'lenna','sial','iele','alee','nia','vara','lathe','enneth','riel','nairra','laqui',
            'astra','ava','thia','ania']
    
    #list of male first name suffixes
    gent = ['las','erth','dran','lar','amil','annis','eiro','ust','ill','ric','alis','dan','van',
           'inndan','darai','ian','mo','meral','ral','llios', 'illos','cian','dartis','eilas','ren',
           'rion','mior','liss','len','rivol','ris']
    
    #lists of surname in syllables
    sur1 = ['Moon','Sun','Star','Gem','Diamond','Silver', 'Night','Gold','Oaken' ,'Wind','Ruby','Sapphire']
    sur2 = ['dancer','speaker','ranger','flower','dew','whisper','frond','breeze',
            'petal','heel','brook','leaf','river','sea','shine']
    
    #creating last name
    last = sur1[random.randrange(0,len(sur1),1)]+sur2[random.randrange(0,len(sur2),1)]
    
    
    if gender == 'f':
        #creating first name
        n1 = pref[random.randrange(0,len(pref),1)]
        n2 = lady[random.randrange(0,len(lady),1)]
        #print full name
        #print("{}{} {}".format(n1, n2,last))
        return n1+n2, last
        
    if gender == 'm':
        #creating first name
        n3 = pref[random.randrange(0,len(pref),1)]
        n4 = gent[random.randrange(0,len(gent),1)]
        #print fullname
        #print("{}{} {}".format(n3, n4,last))
        return n3+n4, last

# %%
def human_name(gender, sub=None):
    
    #list of subraces
    subraces = ['Calishite', 'Chondathan','Illuskan','Damaran','Mulan','Rashemi','Shou','Tethyrian','Turami']
    
    #lists of female first names by subrace
    lady = {'Calishite':['Atala','Ceidil','Hama','Jasmal','Meilil','Seipore', 'Yasheira','Zasheida'], 
            'Chondathan':['Arveene','Esvele','Jhessail', 'Kerri','Lureene','Miri','Rowan','Shandri','Tessele'],
            'Damaran':['Alethra','Kara','Katerinn','Mara','Natali','Olma','Tana','Zora'],
            'Illuskan':['Amafrey','Betha','Cefrey','Kethra', 'Marina','Olja','Silifrey','Westra'],
            'Mulan':['Arizima','Chathi','Nephis','Nulara','Murithi','Sefris','Thola','Umara','Zolis'],
            'Rashemi':['Fyevarra','Hulmarra','Immith','Imzel','Navarra','Shevarra','Tammith','Yuldra'],
            'Shou':['Bai','Chao','Jia','Lei','Mei','Qiao','Shui','Tai'],
            'Tethyrian':['Arveene','Esvele','Jhessail', 'Kerri','Lureene','Miri','Rowan','Shandri','Tessele'],
            'Turami':['Balama','Dona','Faila','Jalana','Luisa','Marta','Quara','Selise','Vonda']}
    
    #lists of male first names by subrace
    gent = {'Calishite':['Aseir','Bardeid','Haseid','Jasnah','Khemed','Mehmen', 'Wessam', 'Sudeiman', 'Zasheir'], 
            'Chondathan':['Darvin','Dorn','Evendur','Gorstag','Grim','Helm','Malark','Morn','Randal','Stedd'],
            'Damaran':['Bor','Fodel','Glar','Grigor','Igan','Ivor','Kosef','Mival','Orel','Pavel','Sergor'],
            'Illuskan':['Ander','Blath','Bran','Frath','Geth','Lander','Luth','Malcer','Stor','Taman','Urth'],
            'Mulan':['Aoth','Bareris','Ehput-Ki','Kethoth','Mumed','Ramas','So-Kehur','Thazar-De','Urthur'],
            'Rashemi':['Borivik','Faurgar','Jandar','Kanithar','Madislak','Ralmevik','Shaumar','Vladislak'],
            'Shou':['An','Chen','Chi','Fai','Jiang','Jun','Lian','Long','Meng','On','Shan','Shui','Tai','Var'],
            'Tethyrian':['Darvin','Dorn','Evendur','Gorstag','Grim','Helm','Malark','Morn','Randal','Stedd'],
            'Turami':['Anton','Diero','Marcon','Pieron','Rimardo','Romero','Salazar','Umbero']}
    
    #lists of surnames by subrace
    sur = {'Calishite':['Basha','Badawi','Dumein','Jassan','Khalid','Mostana','Pashar','Rein'], 
            'Chondathan':['Amblecrown','Buckman','Dundragon','Evenwood','Greycastle','Tallstag'],
            'Damaran':['Bersk','Chernin','Dotsk','Kulenov','Marsk','Nemetsk','Shemov','Starag','Kuzko'],
            'Illuskan':['Brightwood','Helder','Lannister','Hornraven','Lackman','Stormwind','Windrivver'],
            'Mulan':['Ankhalab','Anskuld','Fezim','Haphet','Nathandem','Sepret','Uuthrakt'],
            'Rashemi':['Chergoba','Dyernina','Iltazyara','Murnyethara','Stayanoga','Ulmokina','Zahera'],
            'Shou':['Chien','Huang','Kao','Kung','Lao','Ling','Mei','Pin','Shin','Sum','Faa','Tan','Wan'],
            'Tethyrian':['Amblecrown','Buckman','Dundragon','Evenwood','Greycastle','Tallstag'],
            'Turami':['Agosto','Astorio','Calabra','Domine','Falone','Marivaldi','Pisacar','Ramondo']}
 
    if sub in subraces:
        #creating last name
        last1 = sur[sub][random.randrange(0,len(sur[sub]),1)]
        
        if gender == 'f':
            #creating first name
            n1 = lady[sub][random.randrange(0,len(lady[sub]),1)]
            #print full name
            print("{} {}".format(n1,last1))
            return [n1, last1]

        if gender == 'm':
            #creating first name
            n2 = gent[sub][random.randrange(0,len(gent[sub]),1)]
            #print fullname
            print("{} {}".format(n2,last1))
            return [n2, last1]
    
    elif sub == None:
        
        subs = subraces[random.randrange(0,len(subraces),1)]
        
        #creating last name
        last2 = sur[subs][random.randrange(0,len(sur[subs]),1)]

        if gender == 'f':
            #creating first name
            n3 = lady[subs][random.randrange(0,len(lady[subs]),1)]
            #print full name
            #print("{} {}".format(n3,last2))
            return n3, last2

        if gender == 'm':
            #creating first name
            n4 = gent[subs][random.randrange(0,len(gent[subs]),1)]
            #print fullname
            #print("{} {}".format(n4,last2))
            return n4, last2

# %%
def halfelf_name(gender):
    #race basis for naming 
    halves = ['elf','human']
    
    #random base for first and last names
    half1 = halves[random.randrange(0,len(halves),1)]
    half2 = halves[random.randrange(0,len(halves),1)]
    
    #last name generator
    if half1 == 'elf':
        last = elf_name(gender)[1]
    elif half1 == 'human':
        last = human_name(gender, sub=None)[1]
        
    #first name generator
    if half2 == 'elf':
        first = elf_name(gender)[0]
    elif half2 == 'human':
        first = human_name(gender, sub=None)[0]
        
    return first, last

# %%
def dragonborn_name(gender):
    #list of first name prefixes
    pref = ['Arj','Ka','Bal','Bhar','Don','Ghe','Hes','Kri','Medr','Meh', 'Nad','Pandr','Pat','Rho',
            'Sham','Shed','Tar','Tor','Ak','Bir','Da','Far','Har','Hav','Jhe','Kor','Mish','Nal','Per',
            'Rai','Sor','Su','Tha','Uad']
    
    #list of female first name suffixes
    lady = ['ra','ri','a','ara','eh','ann','ilar','eri','ari','la','a','ina','jit','jita','elas']
    
    #list of male first name suffixes
    gent = ['han','asar','rash','v','aar','esh','kan','gar','ash','inn','n','hun','r','s','k']
    
    #list of surnames
    sur = ['Clethinthiallor','Daardendrian','Delmirev','Zagourachenk','Drachedandion','Fenkenkabradon',
          'Kepeshkmolik','Kerrhylon','Blutinvolor','Kimbatuul','Linxakasendalor','Myastan','Nemmonis',
           'Norixius','Ophinshtalajir','Prexijandilin','Shestendeliath','Turnoroth', 'Tunroc',
           'Verthisathurgiesh','Yarjerit','Atmanjith']
    
    #creating last name
    last = sur[random.randrange(0,len(sur),1)]
    
    #Choosing first name syllables
    n1 = pref[random.randrange(0,len(pref),1)]
    
    if gender == 'f':
        #creating first name
        n2 = lady[random.randrange(0,len(lady),1)]
        #print full name
        return n1+n2, last
        
    if gender == 'm':
        #creating first name
        n3 = gent[random.randrange(0,len(gent),1)]
        #print fullname
        return n1+n3, last

# %%
def tiefling_name(gender, virtue = None):
    #list of male names
    gent1 = ['Ak','Am','Bar','Bro','Dam','Dand','Ek','Ia','Kai','Leu','Mel',
             'Mor','Mat','Pel','Ska','The','Zhi']
    gent2 = ['menos','non','akas','akos','mon','dos','ron','cis','ech','ach',
             'dai','chai','thos','ios','mos','ai']
    
    #list of female names
    lady1 = ['Ak','Ana','Bry','Cri','Dam','E','Kal','Ler','Mak','Mara','Nem',
             'Ori','Phel','Ri','Ki','Ane','Sha', 'Xri']
    lady2 = ['ta','kis','seis','ella','aia','a','ena','lista','issa','aria',
             'eia','anna','aia','eta','ita','alta']
    
    #list of virtue names
    v = ['Art','Carrion','Chant','Creed','Despair','Excellence','Fear','Glory','Hope',
            'Ideal','Music','Nowhere','Open','Poetry','Quest','Random','Reverence','Sorrow',
            'Temerity','Torment','Weary', 'Courage','Bravery','Temperance','Magnificance',
            'Magnamity', 'Moderation','Magnificence','Magnanimity','Generosity','Ambition',
            'Pride','Patience','Calm','Truthfulness','Honesty','Wit','Humor','Modesty','Ego',
            'Justice','Indignation','Greed', 'Perserverance']
    
    if not virtue:
        
        if gender == 'm':
            n1 = gent1[random.randrange(0,len(gent1),1)]
            n2 = gent2[random.randrange(0,len(gent2),1)]
            return n1+n2
        
        if gender == 'f':
            n3 = lady1[random.randrange(0,len(lady1),1)]
            n4 = lady2[random.randrange(0,len(lady2),1)]
            return n3+n4
        
    elif virtue == 'yes':
        n5 = v[random.randrange(0,len(v),1)]
        return n5

# %%
def halfling_name(gender):
    #lists of female first name in syllables
    lady1 = ['And','Br','Cal','Co','Euphe','Jill','Kith','Lavi','Lid','Mer','Ned',
             'Pa','Por','Seraph','Sha','Tr','V','Ver']
    lady2 =['ry','ee','lie','ra','mia','ian','ri','nia','la','da','li','tia',
            'shia','ina','ena','ni','na']
    
    #lists of male first name in syllables
    gent1 = ['Al','An','C','Cor','El','Er','Finn','Gar','Lin','Ly','Mer','Mi','Pip',
             'Osb','Per','Re','Ros','Well','Fro','Tor']
    gent2 = ['by','coe','coe','ed','rin','orn','lo','ric','le','dal','ret','nan',
             'rich','don','der','ton','do','dy']
    
    #lists of surname in syllables
    sur1 = ['Good','Brush','Green','High','Hill','Lea','Tea','Thorn','Toss','Under','Fall','Copper']
    sur2 = ['barrow','meadow','','barrel','gallow','leaf','hill','topple','gage','cobble','bough','berry']
    
    #creating last name
    last = sur1[random.randrange(0,len(sur1),1)]+sur2[random.randrange(0,len(sur2),1)]
    
    if gender == 'f':
        #creating first name
        n1 = lady1[random.randrange(0,len(lady1),1)]
        n2 = lady2[random.randrange(0,len(lady2),1)]
      
        return n1+n2, last
        
    if gender == 'm':
        #creating first name
        n3 = gent1[random.randrange(0,len(gent1),1)]
        n4 = gent2[random.randrange(0,len(gent2),1)]

        return n3+n4, last

# %%
def gnome_name(gender):
    # list of male firstnames
    gent = ['Alston','Alvyn','Boddynock','Brocc','Burgell','Dimble','Eldon','Erky','Fonkin','Frug','Gimble',
            'Glim','Jebeddo','Kellen','Namfoodle','Orryn','Roondar','Seebo','Sindri','Warryn','Wrenn','Zook']
    
    #list of female firstnames
    lady = ['Bimpnottin','Breena','Caramip','Carlin','Loopmottin','Lorilla','Donella','Duvamil','Ella',
            'Ellyjobell','Ellywick','Lilli','Mardnab','Nissa','Nyx','Oda','Orla','Roywyn','Shamil','Tana'
           'Waywrocket','Zanna']
    
    #list of common nicknames
    nick = ['Aleslosh','Ashhearth','Badger','Cloak','Doublelock','Filchbatter','Fnipper','Ku', 'Nim',
            'Oneshoe','Pock','Sparklegem','Stumbleduck']
    
    #list of clannames
    clan = ['Beren','Daergel','Folkor','Garrick','Nackle','Murnig','Ningel','Raulnor','Scheppen','Timbers'
          'Turen','Shendrew','Pengkim']
    
    last = clan[random.randrange(0,len(clan),1)]
    
    
    n1 = nick[random.randrange(0,len(nick),1)]

    if gender == 'm':
        n2 = gent[random.randrange(0,len(gent),1)]
        return n2, n1, last
        
    if gender == 'f':
        n3 = lady[random.randrange(0,len(lady),1)]
        return n3, n1, last
        
    
##add more with a for loop of anywhere from 4-10 names plus a nickname and a clan name

# %%
def halforc_name(gender):
    return None

# %%
def gen_name(race, gender, hu_sub=None, virtue=None):
    races=['dwarf', 'elf', 'human', 'half-elf','dragonborn', 'tiefling','halfling','gnome']
    
    if race not in races:
        print("That race is not yet supported.")
        
    else:
        if race == 'dwarf':
            first, last = dwarf_name(gender)
            print(first, last)
            
        if race == 'elf':
            first, last = elf_name(gender)
            print(first, last)
            
        if race == 'human':
            first, last = human_name(gender, sub=hu_sub)
            print(first, last)
            
        if race == 'half-elf':
            first, last = halfelf_name(gender)
            print(first, last)
            
        if race == 'dragonborn':
            first, last = dragonborn_name(gender)
            print(first, last)    
        
        if race == 'tiefling':
            tief = tiefling_name(gender, virtue=virtue)
            print(tief)
            
        if race == 'halfling':
            first, last = halfling_name(gender)
            print(first, last)
            
        if race == 'gnome':
            first, nickname, last = gnome_name(gender)
            print(first,'\'',nickname,'\'' , last)

# %%
gen_name('gnome','m', hu_sub=None, virtue= None)
# Out:
# Sindri ' Nim ' Ningel
